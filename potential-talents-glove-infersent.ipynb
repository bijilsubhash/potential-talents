# %% [markdown]
# # Dependencies

# %%
from models import InferSent
import torch

import pandas as pd
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

import re

from scipy import spatial

import requests
import urllib.parse

import geopy.distance
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Downloading the pretrained model and vectors

# %%
#saving the trained model and pre-trained GLoVe word vectors
! mkdir encoder
! curl -Lo encoder/infersent1.pkl https://dl.fbaipublicfiles.com/infersent/infersent1.pkl #glove model
! curl -Lo encoder/infersent2.pkl https://dl.fbaipublicfiles.com/infersent/infersent2.pkl #fasttext model
  
! mkdir GloVe
! curl -Lo GloVe/glove.840B.300d.zip http://nlp.stanford.edu/data/glove.840B.300d.zip
! unzip GloVe/glove.840B.300d.zip -d GloVe/

# %% [markdown]
# # Reading the data

# %%
df = pd.read_csv('potential-talents.csv')
df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 99              Cape Girardeau, Missouri        103  NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 101           Greater New York City Area         49  NaN
# 102             Greater Los Angeles Area      500+   NaN
# 103                          Katy, Texas      500+   NaN
#
# [104 rows x 5 columns]

# %%
#using openstreetmap api to get the lattitude and longitude of the location - which will be later used for ranking
def location(city_name):
    url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(city_name) +'?format=json'
    response = requests.get(url).json()
    lat = float(response[0]['lat'])
    lon = float(response[0]['lon'])
    return lat,lon

# %%
#testing if all location is recognized by openstreetmap api
locs = df.location.unique()
for loc in locs:
    try: 
        url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(loc) +'?format=json'
        response = requests.get(url).json()
        lat = float(response[0]['lat'])
        lon = float(response[0]['lon'])
        print(loc,': Yes')
    except:
        print(loc,': No')
# Out:
# Houston, Texas : Yes
# Kanada : Yes
# Raleigh-Durham, North Carolina Area : Yes
# Denton, Texas : Yes
# İzmir, Türkiye : Yes
# Greater New York City Area : No
# San Francisco Bay Area : Yes
# Greater Philadelphia Area : Yes
# Lake Forest, California : Yes
# Houston, Texas Area : Yes
# Atlanta, Georgia : Yes
# Chicago, Illinois : Yes
# Austin, Texas Area : Yes
# Jackson, Mississippi Area : Yes
# Greater Grand Rapids, Michigan Area : No
# Virginia Beach, Virginia : Yes
# Monroe, Louisiana Area : Yes
# Greater Boston Area : Yes
# San Jose, California : Yes
# New York, New York : Yes
# Dallas/Fort Worth Area : Yes
# Amerika Birleşik Devletleri : Yes
# Baton Rouge, Louisiana Area : Yes
# Myrtle Beach, South Carolina Area : Yes
# Chattanooga, Tennessee Area : Yes
# Los Angeles, California : Yes
# Highland, California : Yes
# Gaithersburg, Maryland : Yes
# Baltimore, Maryland : Yes
# Milpitas, California : Yes
# Greater Atlanta Area : Yes
# Greater Chicago Area : Yes
# Torrance, California : Yes
# Long Beach, California : Yes
# Bridgewater, Massachusetts : Yes
# Lafayette, Indiana : Yes
# Kokomo, Indiana Area : Yes
# Las Vegas, Nevada Area : Yes
# Cape Girardeau, Missouri : Yes
# Greater Los Angeles Area : No
# Katy, Texas : Yes

# %% [markdown]
# Looks like 3 entries are not recognized by the api:
# - 'Greater New York City Area'
# - 'Greater Grand Rapids, Michigan Area'
# - 'Greater Los Angeles Area'
#
# Changing these in the original dataframe:
# - New York
# - Michigan
# - Los Angeles

# %%
df['location'] = df['location'].replace('Greater New York City Area', 'New York')
df['location'] = df['location'].replace('Greater Grand Rapids, Michigan Area', 'Michigan')
df['location'] = df['location'].replace('Greater Los Angeles Area', 'Los Angeles')

# %%
#sentence preprocessing function
def sentence_transform(sentences):
    lemmatizer = WordNetLemmatizer()
    sentence = re.sub('[^a-zA-Z]', ' ', sentences) #substituing all non-alphabets in a sentence with space
    sentence = sentence.lower() #converting to lowercase
    sentence = nltk.word_tokenize(sentence) #word tokenization
    sentence = [lemmatizer.lemmatize(word) for word in sentence if word not in set(stopwords.words('english'))] #lemmatization
    sentence = ' '.join(sentence) #joining the words to construct the sentence
    return sentence

# %%
#ranking function
def ranking(df, job_query, location_query = None):
    
    #loading model and word embeddings
    V = 1
    MODEL_PATH = 'encoder/infersent%s.pkl' % V
    params_model = {'bsize': 64, 'word_emb_dim': 300, 'enc_lstm_dim': 2048,
                    'pool_type': 'max', 'dpout_model': 0.0, 'version': V}
    model = InferSent(params_model)
    model.load_state_dict(torch.load(MODEL_PATH))

    W2V_PATH = 'GloVe/glove.840B.300d.txt'
    model.set_w2v_path(W2V_PATH)
    
    #sentence pre-processing
    sentences = []
    for idx in range(len(df)):
        sentences.append(sentence_transform(df['job_title'].iloc[idx]))
    
    #build the vocab
    model.build_vocab(sentences, tokenize=True)

    #query embeddings
    query_vec = model.encode([sentence_transform(job_query)])[0]

    #initializing the column for job rankings
    if 'job_title_ranking' not in df:
        df['job_title_ranking'] = np.nan 
    
    #initalizing the column for location rankings
    if location_query != None:
        if 'location_ranking' not in df:
            df['location_ranking'] = np.nan 
        
    #calculating cosine similarity and geograhical distance using openstreetmap api 
    for idx in range(len(df)):
        df['job_title_ranking'].loc[idx] = 1 - spatial.distance.cosine(query_vec, model.encode([sentence_transform(df['job_title'][idx])])[0])
        if location_query != None:
            df['location_ranking'].loc[idx] = geopy.distance.distance(location(location_query), location(df['location'][idx])).km
    
    #ranking logic
        #if job title ranking is greater than 0.5, both job title and location have equal contribution to the fit rank
        #if job title ranking is less than 0.5, then job title accounts for 90% to the fit rank
    if location_query != None:
        min_max_scaler = MinMaxScaler()
        df['location_ranking'] = 1 - min_max_scaler.fit_transform(df[['location_ranking']]) #ranking the geographical distance b/w 0 and 1
        for idx in range(len(df)):
            if df['job_title_ranking'].loc[idx] > 0.5:
                df['fit'].loc[idx] = 0.5 * df['job_title_ranking'].loc[idx] + 0.5 * df['location_ranking'].loc[idx]
            else:
                df['fit'].loc[idx] = 0.9 * df['job_title_ranking'].loc[idx] + 0.1 * df['location_ranking'].loc[idx]
    else:
        df['fit'] = df['job_title_ranking'] #if location is not included in query
        
    return df

# %%
#initial ranking
job_query = 'seeking human resources'
location_query = 'texas'
initial_rank = df
initial_rank = ranking(initial_rank, job_query, location_query)
initial_rank
# Out:
# Found 172(/181) words with w2v vectors
# Vocab size : 172
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection       fit  \
# 0                         Houston, Texas         85  0.451804
# 1                                 Kanada      500+   0.292748
# 2    Raleigh-Durham, North Carolina Area         44  0.813427
# 3                          Denton, Texas      500+   0.530772
# 4                         İzmir, Türkiye      500+   0.273993
# ..                                   ...        ...       ...
# 99              Cape Girardeau, Missouri        103  0.721292
# 100  Raleigh-Durham, North Carolina Area      500+   0.838018
# 101                             New York         49  0.647383
# 102                          Los Angeles      500+   0.399766
# 103                          Katy, Texas      500+   0.507263
#
#      job_title_ranking  location_ranking
# 0             0.393391      9.775191e-01
# 1             0.248240      6.933263e-01
# 2             0.800410      8.264443e-01
# 3             0.479895      9.886667e-01
# 4             0.304437      1.110223e-16
# ..                 ...               ...
# 99            0.534105      9.084785e-01
# 100           0.849592      8.264443e-01
# 101           0.519763      7.750032e-01
# 102           0.349830      8.491880e-01
# 103           0.454562      9.815774e-01
#
# [104 rows x 7 columns]

# %%
#top 50
initial_rank.sort_values(by='fit', ascending=False)[0:50]
# Out:
#       id                                          job_title  \
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 98    99                   Seeking Human Resources Position
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 100  101              Human Resources Generalist at Loparex
# 26    27  Aspiring Human Resources Management student se...
# 28    29  Aspiring Human Resources Management student se...
# 96    97              Aspiring Human Resources Professional
# 93    94  Seeking Human  Resources Opportunities. Open t...
# 20    21              Aspiring Human Resources Professional
# 57    58              Aspiring Human Resources Professional
# 45    46              Aspiring Human Resources Professional
# 16    17              Aspiring Human Resources Professional
# 2      3              Aspiring Human Resources Professional
# 32    33              Aspiring Human Resources Professional
# 66    67  Human Resources, Staffing and Recruiting Profe...
# 77    78             Human Resources Generalist at Schwan's
# 67    68            Human Resources Specialist at Luxottica
# 81    82  Aspiring Human Resources Professional | An ene...
# 65    66  Experienced Retail Manager and aspiring Human ...
# 71    72  Business Management Major and Aspiring Human R...
# 76    77  Human Resources|\nConflict Management|\nPolici...
# 35    36                Aspiring Human Resources Specialist
# 23    24                Aspiring Human Resources Specialist
# 48    49                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
# 59    60                Aspiring Human Resources Specialist
# 87    88                   Human Resources Management Major
# 70    71    Human Resources Generalist at ScottMadden, Inc.
# 74    75  Nortia Staffing is seeking Human Resources, Pa...
# 78    79  Liberal Arts Major. Aspiring Human Resources A...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 83    84  Human Resources professional for the world lea...
# 99   100  Aspiring Human Resources Manager | Graduating ...
#
# 29            0.943102          0.865276
# 27            0.943102          0.865276
# 98            0.929863          0.871787
# 72            0.735719          0.974446
# 100           0.849592          0.826444
# 26            0.697651          0.974446
# 28            0.697651          0.974446
# 96            0.800410          0.865760
# 93            0.701601          0.927620
# 20            0.800410          0.826444
# 57            0.800410          0.826444
# 45            0.800410          0.826444
# 16            0.800410          0.826444
# 2             0.800410          0.826444
# 32            0.800410          0.826444
# 66            0.707533          0.916702
# 77            0.693735          0.927620
# 67            0.837910          0.775003
# 81            0.605785          1.000000
# 65            0.595472          1.000000
# 71            0.641018          0.949716
# 76            0.599335          0.989479
# 35            0.809110          0.775003
# 23            0.809110          0.775003
# 48            0.809110          0.775003
# 5             0.809110          0.775003
# 59            0.809110          0.775003
# 87            0.769124          0.811848
# 70            0.738005          0.826444
# 74            0.704471          0.812189
# 78            0.565424          0.940861
# 61            0.682086          0.786756
# 39            0.682086          0.786756
# 9             0.682086          0.786756
# 52            0.682086          0.786756
# 83            0.608805          0.858563
# 99            0.534105          0.908479
# 80            0.558923          0.883289
# 91            0.544743          0.848514
# 75            0.588758          0.775003
# 101           0.519763          0.775003
# 51            0.554464          0.693326
# 38            0.554464          0.693326
# 24            0.554464          0.693326
# 36            0.554464          0.693326
# 6             0.554464          0.693326
# 49            0.554464          0.693326
# 8             0.554464          0.693326
# 73            0.834071          0.249688
# 58            0.479895          0.988667

# %%
#rank 50-100
initial_rank.sort_values(by='fit', ascending=False)[50:100]
# Out:
#       id                                          job_title  \
# 3      4             People Development Coordinator at Ryan
# 21    22             People Development Coordinator at Ryan
# 33    34             People Development Coordinator at Ryan
# 46    47             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 69    70  Retired Army National Guard Recruiter, office ...
# 55    56  Human Resources Coordinator at InterContinenta...
# 64    65  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 103  104   Director Of Administration at Excellence Logging
# 85    86  Information Systems Specialist and Programmer ...
# 88    89                    Director Human Resources  at EY
# 79    80           Junior MES Engineer| Information Systems
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 56    57  2019 C.T. Bauer College of Business Graduate (...
# 13    14  2019 C.T. Bauer College of Business Graduate (...
# 14    15  2019 C.T. Bauer College of Business Graduate (...
# 18    19  2019 C.T. Bauer College of Business Graduate (...
# 43    44  2019 C.T. Bauer College of Business Graduate (...
# 30    31  2019 C.T. Bauer College of Business Graduate (...
# 68    69  Director of Human Resources North America, Gro...
# 37    38                               HR Senior Specialist
# 7      8                               HR Senior Specialist
# 25    26                               HR Senior Specialist
# 60    61                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 89    90  Undergraduate Research Assistant at Styczynski...
# 92    93  Admissions Representative at Community medical...
# 86    87  Bachelor of Science in Biology from Victoria U...
# 97    98                                            Student
# 102  103                     Always set them up for Success
# 10    11                      Student at Chapman University
# 40    41                      Student at Chapman University
# 62    63                      Student at Chapman University
# 53    54                      Student at Chapman University
# 54    55  SVP, CHRO, Marketing & Communications, CSR Off...
# 11    12  SVP, CHRO, Marketing & Communications, CSR Off...
# 63    64  SVP, CHRO, Marketing & Communications, CSR Off...
# 41    42  SVP, CHRO, Marketing & Communications, CSR Off...
# 90    91       Lead Official at Western Illinois University
# 94    95              Student at Westfield State University
# 84    85  RRP Brand Portfolio Executive at JTI (Japan To...
# 95    96  Student at Indiana University Kokomo - Busines...
# 1      2  Native English Teacher at EPIK (English Progra...
# 31    32  Native English Teacher at EPIK (English Progra...
# 15    16  Native English Teacher at EPIK (English Progra...
# 19    20  Native English Teacher at EPIK (English Progra...
# 44    45  Native English Teacher at EPIK (English Progra...
# 82    83          HR Manager at Endemol Shine North America
#
#                               location connection       fit  \
# 3                        Denton, Texas      500+   0.530772
# 21                       Denton, Texas      500+   0.530772
# 33                       Denton, Texas      500+   0.530772
# 46                       Denton, Texas      500+   0.530772
# 17                       Denton, Texas      500+   0.530772
# 69            Virginia Beach, Virginia         82  0.521476
# 55                    Atlanta, Georgia      500+   0.511090
# 64                    Atlanta, Georgia      500+   0.511090
# 42                    Atlanta, Georgia      500+   0.511090
# 12                    Atlanta, Georgia      500+   0.511090
# 103                        Katy, Texas      500+   0.507263
# 85              Gaithersburg, Maryland          4  0.500983
# 88                Greater Atlanta Area        349  0.499976
# 79   Myrtle Beach, South Carolina Area         52  0.453621
# 0                       Houston, Texas         85  0.451804
# 56                      Houston, Texas         85  0.451804
# 13                      Houston, Texas         85  0.451804
# 14                      Houston, Texas         85  0.451804
# 18                      Houston, Texas         85  0.451804
# 43                      Houston, Texas         85  0.451804
# 30                      Houston, Texas         85  0.451804
# 68                            Michigan      500+   0.432070
# 37              San Francisco Bay Area      500+   0.431612
# 7               San Francisco Bay Area      500+   0.431612
# 25              San Francisco Bay Area      500+   0.431612
# 60              San Francisco Bay Area      500+   0.431612
# 50              San Francisco Bay Area      500+   0.431612
# 89                Greater Atlanta Area        155  0.425213
# 92              Long Beach, California          9  0.420691
# 86                 Baltimore, Maryland         40  0.415245
# 97                 Houston, Texas Area          4  0.406601
# 102                        Los Angeles      500+   0.399766
# 10             Lake Forest, California          2  0.386470
# 40             Lake Forest, California          2  0.386470
# 62             Lake Forest, California          2  0.386470
# 53             Lake Forest, California          2  0.386470
# 54                 Houston, Texas Area      500+   0.382161
# 11                 Houston, Texas Area      500+   0.382161
# 63                 Houston, Texas Area      500+   0.382161
# 41                 Houston, Texas Area      500+   0.382161
# 90                Greater Chicago Area         39  0.370006
# 94          Bridgewater, Massachusetts         57  0.362915
# 84           Greater Philadelphia Area      500+   0.337691
# 95                  Lafayette, Indiana         19  0.313038
# 1                               Kanada      500+   0.292748
# 31                              Kanada      500+   0.292748
# 15                              Kanada      500+   0.292748
# 19                              Kanada      500+   0.292748
# 44                              Kanada      500+   0.292748
# 82             Los Angeles, California        268  0.276531
#
#      job_title_ranking  location_ranking
# 3             0.479895          0.988667
# 21            0.479895          0.988667
# 33            0.479895          0.988667
# 46            0.479895          0.988667
# 17            0.479895          0.988667
# 69            0.490478          0.800463
# 55            0.470254          0.878619
# 64            0.470254          0.878619
# 42            0.470254          0.878619
# 12            0.470254          0.878619
# 103           0.454562          0.981577
# 85            0.467193          0.805097
# 88            0.752806          0.247146
# 79            0.411892          0.829180
# 0             0.393391          0.977519
# 56            0.393391          0.977519
# 13            0.393391          0.977519
# 14            0.393391          0.977519
# 18            0.393391          0.977519
# 43            0.393391          0.977519
# 30            0.393391          0.977519
# 68            0.387254          0.835411
# 37            0.389873          0.807264
# 7             0.389873          0.807264
# 25            0.389873          0.807264
# 60            0.389873          0.807264
# 50            0.389873          0.807264
# 89            0.444998          0.247146
# 92            0.373001          0.849901
# 86            0.372497          0.799970
# 97            0.343507          0.974446
# 102           0.349830          0.849188
# 10            0.334464          0.854524
# 40            0.334464          0.854524
# 62            0.334464          0.854524
# 53            0.334464          0.854524
# 54            0.316351          0.974446
# 11            0.316351          0.974446
# 63            0.316351          0.974446
# 41            0.316351          0.974446
# 90            0.314897          0.865984
# 94            0.320172          0.747593
# 84            0.287795          0.786756
# 95            0.251040          0.871018
# 1             0.248240          0.693326
# 31            0.248240          0.693326
# 15            0.248240          0.693326
# 19            0.248240          0.693326
# 44            0.248240          0.693326
# 82            0.212902          0.849188

# %%
#suppose from the above we notice that id 82 is the ideal candidate (19th in top 50)
job_query = initial_rank['job_title'].loc[81]
location_query = initial_rank['location'].loc[81]
re_rank = ranking(initial_rank, job_query, location_query)
re_rank
# Out:
# Found 172(/181) words with w2v vectors
# Vocab size : 172
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection       fit  \
# 0                         Houston, Texas         85  0.825222
# 1                                 Kanada      500+   0.492106
# 2    Raleigh-Durham, North Carolina Area         44  0.824122
# 3                          Denton, Texas      500+   0.761336
# 4                         İzmir, Türkiye      500+   0.376484
# ..                                   ...        ...       ...
# 99              Cape Girardeau, Missouri        103  0.813631
# 100  Raleigh-Durham, North Carolina Area      500+   0.721848
# 101                             New York         49  0.679043
# 102                          Los Angeles      500+   0.416930
# 103                          Katy, Texas      500+   0.768707
#
#      job_title_ranking  location_ranking
# 0             0.672960      9.774830e-01
# 1             0.472771      6.661207e-01
# 2             0.826465      8.217797e-01
# 3             0.553975      9.686977e-01
# 4             0.418315      1.110223e-16
# ..                 ...               ...
# 99            0.731053      8.962081e-01
# 100           0.621916      8.217797e-01
# 101           0.589998      7.680892e-01
# 102           0.373040      8.119406e-01
# 103           0.555800      9.816142e-01
#
# [104 rows x 7 columns]

# %%
#top 50
re_rank.sort_values(by='fit', ascending=False)[0:50]
# Out:
#       id                                          job_title  \
# 81    82  Aspiring Human Resources Professional | An ene...
# 65    66  Experienced Retail Manager and aspiring Human ...
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 28    29  Aspiring Human Resources Management student se...
# 26    27  Aspiring Human Resources Management student se...
# 71    72  Business Management Major and Aspiring Human R...
# 66    67  Human Resources, Staffing and Recruiting Profe...
# 96    97              Aspiring Human Resources Professional
# 78    79  Liberal Arts Major. Aspiring Human Resources A...
# 14    15  2019 C.T. Bauer College of Business Graduate (...
# 56    57  2019 C.T. Bauer College of Business Graduate (...
# 30    31  2019 C.T. Bauer College of Business Graduate (...
# 18    19  2019 C.T. Bauer College of Business Graduate (...
# 0      1  2019 C.T. Bauer College of Business Graduate (...
#
# 57   Raleigh-Durham, North Carolina Area         44  0.824122
# 76                Dallas/Fort Worth Area        409  0.817050
# 99              Cape Girardeau, Missouri        103  0.813631
# 75                    New York, New York        212  0.812941
# 83                  Highland, California         50  0.807721
# 80           Chattanooga, Tennessee Area        455  0.793736
# 93           Amerika Birleşik Devletleri        415  0.784263
# 29                     Chicago, Illinois        390  0.772070
# 27                     Chicago, Illinois        390  0.772070
# 5                               New York          1  0.769484
# 59                              New York          1  0.769484
# 23                              New York          1  0.769484
# 35                              New York          1  0.769484
# 48                              New York          1  0.769484
# 63                   Houston, Texas Area      500+   0.769190
# 41                   Houston, Texas Area      500+   0.769190
# 54                   Houston, Texas Area      500+   0.769190
# 11                   Houston, Texas Area      500+   0.769190
# 103                          Katy, Texas      500+   0.768707
# 77           Amerika Birleşik Devletleri      500+   0.763813
# 17                         Denton, Texas      500+   0.761336
# 46                         Denton, Texas      500+   0.761336
# 21                         Denton, Texas      500+   0.761336
# 58                         Denton, Texas      500+   0.761336
# 33                         Denton, Texas      500+   0.761336
# 3                          Denton, Texas      500+   0.761336
# 74                  San Jose, California      500+   0.753539
# 98                Las Vegas, Nevada Area         48  0.746783
# 69              Virginia Beach, Virginia         82  0.743165
#
#      job_title_ranking  location_ranking
# 81            1.000000          1.000000
# 65            0.793362          1.000000
# 72            0.803448          0.974569
# 28            0.790533          0.974569
# 26            0.790533          0.974569
# 71            0.775664          0.943851
# 66            0.784002          0.915590
# 96            0.826465          0.852911
# 78            0.720125          0.939438
# 14            0.672960          0.977483
# 56            0.672960          0.977483
# 30            0.672960          0.977483
# 18            0.672960          0.977483
# 0             0.672960          0.977483
# 13            0.672960          0.977483
# 43            0.672960          0.977483
# 16            0.826465          0.821780
# 45            0.826465          0.821780
# 2             0.826465          0.821780
# 20            0.826465          0.821780
# 32            0.826465          0.821780
# 57            0.826465          0.821780
# 76            0.661602          0.972498
# 99            0.731053          0.896208
# 75            0.857793          0.768089
# 83            0.794318          0.821124
# 80            0.710307          0.877165
# 93            0.671774          0.896752
# 29            0.694215          0.849925
# 27            0.694215          0.849925
# 5             0.770880          0.768089
# 59            0.770880          0.768089
# 23            0.770880          0.768089
# 35            0.770880          0.768089
# 48            0.770880          0.768089
# 63            0.563811          0.974569
# 41            0.563811          0.974569
# 54            0.563811          0.974569
# 11            0.563811          0.974569
# 103           0.555800          0.981614
# 77            0.630874          0.896752
# 17            0.553975          0.968698
# 46            0.553975          0.968698
# 21            0.553975          0.968698
# 58            0.553975          0.968698
# 33            0.553975          0.968698
# 3             0.553975          0.968698
# 74            0.731936          0.775141
# 98            0.659803          0.833763
# 69            0.690480          0.795849

# %%
#rank 50-100
re_rank.sort_values(by='fit', ascending=False)[50:100]
# Out:
#       id                                          job_title  \
# 42    43  Human Resources Coordinator at InterContinenta...
# 64    65  Human Resources Coordinator at InterContinenta...
# 55    56  Human Resources Coordinator at InterContinenta...
# 6                                 Kanada         61  0.676657
# 51                                Kanada         61  0.676657
# 38                                Kanada         61  0.676657
# 24                                Kanada         61  0.676657
# 68                              Michigan      500+   0.670964
# 84             Greater Philadelphia Area      500+   0.519862
# 92                Long Beach, California          9  0.515877
# 50                San Francisco Bay Area      500+   0.507011
# 37                San Francisco Bay Area      500+   0.507011
# 25                San Francisco Bay Area      500+   0.507011
# 60                San Francisco Bay Area      500+   0.507011
# 7                 San Francisco Bay Area      500+   0.507011
# 86                   Baltimore, Maryland         40  0.499679
# 44                                Kanada      500+   0.492106
# 31                                Kanada      500+   0.492106
# 1                                 Kanada      500+   0.492106
# 19                                Kanada      500+   0.492106
# 15                                Kanada      500+   0.492106
# 73                   Greater Boston Area         16  0.485272
# 90                  Greater Chicago Area         39  0.464123
# 82               Los Angeles, California        268  0.460201
# 88                  Greater Atlanta Area        349  0.420659
# 94            Bridgewater, Massachusetts         57  0.419325
# 102                          Los Angeles      500+   0.416930
# 89                  Greater Atlanta Area        155  0.396648
# 10               Lake Forest, California          2  0.378935
# 53               Lake Forest, California          2  0.378935
# 62               Lake Forest, California          2  0.378935
# 40               Lake Forest, California          2  0.378935
# 47                        İzmir, Türkiye      500+   0.376484
#
#      job_title_ranking  location_ranking
# 42            0.588008      8.744070e-01
# 64            0.588008      8.744070e-01
# 55            0.588008      8.744070e-01
# 12            0.588008      8.744070e-01
# 9             0.676215      7.800236e-01
# 39            0.676215      7.800236e-01
# 61            0.676215      7.800236e-01
# 52            0.676215      7.800236e-01
# 85            0.657300      7.982895e-01
# 70            0.627505      8.217797e-01
# 100           0.621916      8.217797e-01
# 91            0.630247      8.113348e-01
# 87            0.639980      7.748009e-01
# 79            0.578517      8.263698e-01
# 67            0.636528      7.680892e-01
# 95            0.528168      8.576002e-01
# 101           0.589998      7.680892e-01
# 8             0.687194      6.661207e-01
# 36            0.687194      6.661207e-01
# 49            0.687194      6.661207e-01
# 6             0.687194      6.661207e-01
# 51            0.687194      6.661207e-01
# 38            0.687194      6.661207e-01
# 24            0.687194      6.661207e-01
# 68            0.520930      8.209985e-01
# 84            0.490955      7.800236e-01
# 92            0.482895      8.127139e-01
# 50            0.477758      7.702797e-01
# 37            0.477758      7.702797e-01
# 25            0.477758      7.702797e-01
# 60            0.477758      7.702797e-01
# 7             0.477758      7.702797e-01
# 86            0.467061      7.932482e-01
# 44            0.472771      6.661207e-01
# 31            0.472771      6.661207e-01
# 1             0.472771      6.661207e-01
# 19            0.472771      6.661207e-01
# 15            0.472771      6.661207e-01
# 73            0.724527      2.460173e-01
# 90            0.421166      8.507359e-01
# 82            0.421119      8.119406e-01
# 88            0.597878      2.434392e-01
# 94            0.383612      7.407395e-01
# 102           0.373040      8.119406e-01
# 89            0.549857      2.434392e-01
# 10            0.330229      8.172858e-01
# 53            0.330229      8.172858e-01
# 62            0.330229      8.172858e-01
# 40            0.330229      8.172858e-01
# 47            0.418315      1.110223e-16
