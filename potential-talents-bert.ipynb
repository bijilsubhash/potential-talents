# %% [markdown]
# # Background:

# %% [markdown]
# As a talent sourcing and management company, we are interested in finding talented individuals for sourcing these candidates to technology companies. Finding talented candidates is not easy, for several reasons. The first reason is one needs to understand what the role is very well to fill in that spot, this requires understanding the client’s needs and what they are looking for in a potential candidate. The second reason is one needs to understand what makes a candidate shine for the role we are in search for. Third, where to find talented individuals is another challenge.
#
# The nature of our job requires a lot of human labor and is full of manual operations. Towards automating this process we want to build a better approach that could save us time and finally help us spot potential candidates that could fit the roles we are in search for. Moreover, going beyond that for a specific role we want to fill in we are interested in developing a machine learning powered pipeline that could spot talented individuals, and rank them based on their fitness.
#
# We are right now semi-automatically sourcing a few candidates, therefore the sourcing part is not a concern at this time but we expect to first determine best matching candidates based on how fit these candidates are for a given role. We generally make these searches based on some keywords such as “full-stack software engineer”, “engineering manager” or “aspiring human resources” based on the role we are trying to fill in. These keywords might change, and you can expect that specific keywords will be provided to you.
#
# Assuming that we were able to list and rank fitting candidates, we then employ a review procedure, as each candidate needs to be reviewed and then determined how good a fit they are through manual inspection. This procedure is done manually and at the end of this manual review, we might choose not the first fitting candidate in the list but maybe the 7th candidate in the list. If that happens, we are interested in being able to re-rank the previous list based on this information. This supervisory signal is going to be supplied by starring the 7th candidate in the list. Starring one candidate actually sets this candidate as an ideal candidate for the given role. Then, we expect the list to be re-ranked each time a candidate is starred.

# %% [markdown]
# # Data Description:

# %% [markdown]
# The data comes from our sourcing efforts. We removed any field that could directly reveal personal details and gave a unique identifier for each candidate.
#
# Attributes:
# id : unique identifier for candidate (numeric)
#
# job_title : job title for candidate (text)
#
# location : geographical location for candidate (text)
#
# connections: number of connections candidate has, 500+ means over 500 (text)
#
# Output (desired target):
# fit - how fit the candidate is for the role? (numeric, probability between 0-1)
#
# Keywords: “Aspiring human resources” or “seeking human resources”

# %% [markdown]
# # Goal(s):

# %% [markdown]
# Predict how fit the candidate is based on their available information (variable fit)

# %% [markdown]
# # Success Metric(s):

# %% [markdown]
# Rank candidates based on a fitness score.
#
# Re-rank candidates when a candidate is starred.

# %% [markdown]
# # Bonus(es):

# %% [markdown]
# We are interested in a robust algorithm, tell us how your solution works and show us how your ranking gets better with each starring action.
#
# How can we filter out candidates which in the first place should not be in this list?
#
# Can we determine a cut-off point that would work for other roles without losing high potential candidates?
#
# Do you have any ideas that we should explore so that we can even automate this procedure to prevent human bias?

# %% [markdown]
# # Dependencies

# %%
import pandas as pd
import numpy as np

from sentence_transformers import SentenceTransformer, util

import requests
import urllib.parse

import geopy.distance
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the data

# %%
df = pd.read_csv('potential-talents.csv')
df
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection  fit
# 0                         Houston, Texas         85  NaN
# 1                                 Kanada      500+   NaN
# 2    Raleigh-Durham, North Carolina Area         44  NaN
# 3                          Denton, Texas      500+   NaN
# 4                         İzmir, Türkiye      500+   NaN
# ..                                   ...        ...  ...
# 99              Cape Girardeau, Missouri        103  NaN
# 100  Raleigh-Durham, North Carolina Area      500+   NaN
# 101           Greater New York City Area         49  NaN
# 102             Greater Los Angeles Area      500+   NaN
# 103                          Katy, Texas      500+   NaN
#
# [104 rows x 5 columns]

# %%
#using openstreetmap api to get the lattitude and longitude of the location - which will be later used for ranking
def location(city_name):
    url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(city_name) +'?format=json'
    response = requests.get(url).json()
    lat = float(response[0]['lat'])
    lon = float(response[0]['lon'])
    return lat,lon

# %%
#changing 3 location names as they weren't being identified by the API
df['location'] = df['location'].replace('Greater New York City Area', 'New York')
df['location'] = df['location'].replace('Greater Grand Rapids, Michigan Area', 'Michigan')
df['location'] = df['location'].replace('Greater Los Angeles Area', 'Los Angeles')

# %%
#ranking function
def ranking(df, job_query, location_query = None):
    
    #loading model and word embeddings
    model = SentenceTransformer('all-MiniLM-L6-v2')
    
    #compute embeddings of job_title
    input_embeddings = model.encode(df['job_title'], convert_to_tensor=True)
    
    #compute embeddings for query
    query_embedding = model.encode(job_query, convert_to_tensor=True)

    #initializing the column for job rankings
    if 'job_title_ranking' not in df:
        df['job_title_ranking'] = np.nan 
    
    #initalizing the column for location rankings
    if location_query != None:
        if 'location_ranking' not in df:
            df['location_ranking'] = np.nan 
        
    #calculating cosine similarity and geograhical distance using openstreetmap api 
    df['job_title_ranking'] = util.cos_sim(query_embedding, input_embeddings)[0]
    if location_query != None:
        for idx in range(len(df)):
            df['location_ranking'].loc[idx] = geopy.distance.distance(location(location_query), location(df['location'][idx])).km
    
    #ranking logic
    #if job title ranking is greater than 0.5, both job title and location have equal contribution to the fit rank
    #if job title ranking is less than 0.5, then job title accounts for 90% to the fit rank
    if location_query != None:
        min_max_scaler = MinMaxScaler()
        df['location_ranking'] = 1 - min_max_scaler.fit_transform(df[['location_ranking']]) #ranking the geographical distance b/w 0 and 1
        for idx in range(len(df)):
            if df['job_title_ranking'].loc[idx] > 0.5:
                df['fit'].loc[idx] = 0.5 * df['job_title_ranking'].loc[idx] + 0.5 * df['location_ranking'].loc[idx]
            else:
                df['fit'].loc[idx] = 0.9 * df['job_title_ranking'].loc[idx] + 0.1 * df['location_ranking'].loc[idx]
    else:
        df['fit'] = df['job_title_ranking'] #if location is not included in query
        
    return df

# %%
#initial ranking
job_query = 'seeking human resources'
location_query = 'texas'
initial_rank = ranking(df, job_query, location_query)
initial_rank
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection       fit  \
# 0                         Houston, Texas         85  0.482357
# 1                                 Kanada      500+   0.271673
# 2    Raleigh-Durham, North Carolina Area         44  0.799572
# 3                          Denton, Texas      500+   0.438381
# 4                         İzmir, Türkiye      500+   0.208569
# ..                                   ...        ...       ...
# 99              Cape Girardeau, Missouri        103  0.792245
# 100  Raleigh-Durham, North Carolina Area      500+   0.727830
# 101                             New York         49  0.209035
# 102                          Los Angeles      500+   0.215943
# 103                          Katy, Texas      500+   0.323407
#
#      job_title_ranking  location_ranking
# 0             0.427339      9.775191e-01
# 1             0.224822      6.933263e-01
# 2             0.772701      8.264443e-01
# 3             0.377238      9.886667e-01
# 4             0.231743      1.110223e-16
# ..                 ...               ...
# 99            0.676011      9.084785e-01
# 100           0.629215      8.264443e-01
# 101           0.146150      7.750032e-01
# 102           0.145582      8.491880e-01
# 103           0.250277      9.815774e-01
#
# [104 rows x 7 columns]

# %%
#top 50
initial_rank.sort_values(by='fit', ascending=False)[0:50]
# Out:
#       id                                          job_title  \
# 98    99                   Seeking Human Resources Position
# 29    30              Seeking Human Resources Opportunities
# 27    28              Seeking Human Resources Opportunities
# 66    67  Human Resources, Staffing and Recruiting Profe...
# 96    97              Aspiring Human Resources Professional
# 81    82  Aspiring Human Resources Professional | An ene...
# 93    94  Seeking Human  Resources Opportunities. Open t...
# 16    17              Aspiring Human Resources Professional
# 32    33              Aspiring Human Resources Professional
# 45    46              Aspiring Human Resources Professional
# 57    58              Aspiring Human Resources Professional
# 2      3              Aspiring Human Resources Professional
# 20    21              Aspiring Human Resources Professional
# 72    73  Aspiring Human Resources Manager, seeking inte...
# 28    29  Aspiring Human Resources Management student se...
# 26    27  Aspiring Human Resources Management student se...
# 39    40  Seeking Human Resources HRIS and Generalist Po...
# 61    62  Seeking Human Resources HRIS and Generalist Po...
# 52    53  Seeking Human Resources HRIS and Generalist Po...
# 9     10  Seeking Human Resources HRIS and Generalist Po...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 77    78             Human Resources Generalist at Schwan's
# 76    77  Human Resources|\nConflict Management|\nPolici...
# 35    36                Aspiring Human Resources Specialist
# 59    60                Aspiring Human Resources Specialist
# 48    49                Aspiring Human Resources Specialist
# 5      6                Aspiring Human Resources Specialist
# 23    24                Aspiring Human Resources Specialist
# 65    66  Experienced Retail Manager and aspiring Human ...
# 71    72  Business Management Major and Aspiring Human R...
# 55    56  Human Resources Coordinator at InterContinenta...
# 42    43  Human Resources Coordinator at InterContinenta...
# 64    65  Human Resources Coordinator at InterContinenta...
# 12    13  Human Resources Coordinator at InterContinenta...
# 70    71    Human Resources Generalist at ScottMadden, Inc.
# 78    79  Liberal Arts Major. Aspiring Human Resources A...
# 100  101              Human Resources Generalist at Loparex
# 75    76  Aspiring Human Resources Professional | Passio...
# 69    70  Retired Army National Guard Recruiter, office ...
# 68    69  Director of Human Resources North America, Gro...
# 87    88                   Human Resources Management Major
# 67    68            Human Resources Specialist at Luxottica
# 83    84  Human Resources professional for the world lea...
# 51    52  Student at Humber College and Aspiring Human R...
# 24    25  Student at Humber College and Aspiring Human R...
# 49    50  Student at Humber College and Aspiring Human R...
# 8      9  Student at Humber College and Aspiring Human R...
# 6      7  Student at Humber College and Aspiring Human R...
# 38    39  Student at Humber College and Aspiring Human R...
# 36    37  Student at Humber College and Aspiring Human R...
#
#                                 location connection       fit  \
# 98                Las Vegas, Nevada Area         48  0.887956
# 29                     Chicago, Illinois        390  0.882224
# 27                     Chicago, Illinois        390  0.882224
# 66             Jackson, Mississippi Area      500+   0.822713
# 96                  Kokomo, Indiana Area         71  0.819230
# 81                    Austin, Texas Area        174  0.810313
# 93           Amerika Birleşik Devletleri        415  0.803369
# 16   Raleigh-Durham, North Carolina Area         44  0.799572
# 32   Raleigh-Durham, North Carolina Area         44  0.799572
# 45   Raleigh-Durham, North Carolina Area         44  0.799572
# 57   Raleigh-Durham, North Carolina Area         44  0.799572
# 2    Raleigh-Durham, North Carolina Area         44  0.799572
# 20   Raleigh-Durham, North Carolina Area         44  0.799572
# 72                   Houston, Texas Area          7  0.799548
# 28                   Houston, Texas Area      500+   0.798626
# 26                   Houston, Texas Area      500+   0.798626
# 39             Greater Philadelphia Area      500+   0.797372
# 61             Greater Philadelphia Area      500+   0.797372
# 52             Greater Philadelphia Area      500+   0.797372
# 9              Greater Philadelphia Area      500+   0.797372
# 99              Cape Girardeau, Missouri        103  0.792245
# 77           Amerika Birleşik Devletleri      500+   0.790610
# 76                Dallas/Fort Worth Area        409  0.778144
# 35                              New York          1  0.777838
# 59                              New York          1  0.777838
# 48                              New York          1  0.777838
# 5                               New York          1  0.777838
# 23                              New York          1  0.777838
# 65                    Austin, Texas Area         57  0.775799
# 71                Monroe, Louisiana Area          5  0.739389
# 55                      Atlanta, Georgia      500+   0.736763
# 42                      Atlanta, Georgia      500+   0.736763
# 64                      Atlanta, Georgia      500+   0.736763
# 12                      Atlanta, Georgia      500+   0.736763
# 70   Raleigh-Durham, North Carolina Area      500+   0.731266
# 78           Baton Rouge, Louisiana Area          7  0.728416
# 100  Raleigh-Durham, North Carolina Area      500+   0.727830
# 75                    New York, New York        212  0.718615
# 69              Virginia Beach, Virginia         82  0.715639
# 68                              Michigan      500+   0.708338
# 87                  Milpitas, California         18  0.706895
# 67                              New York      500+   0.692848
# 83                  Highland, California         50  0.692744
# 51                                Kanada         61  0.661430
# 24                                Kanada         61  0.661430
# 49                                Kanada         61  0.661430
# 8                                 Kanada         61  0.661430
# 6                                 Kanada         61  0.661430
# 38                                Kanada         61  0.661430
# 36                                Kanada         61  0.661430
#
#      job_title_ranking  location_ranking
# 98            0.904125          0.871787
# 29            0.899172          0.865276
# 27            0.899172          0.865276
# 66            0.728724          0.916702
# 96            0.772701          0.865760
# 81            0.620626          1.000000
# 93            0.679118          0.927620
# 16            0.772701          0.826444
# 32            0.772701          0.826444
# 45            0.772701          0.826444
# 57            0.772701          0.826444
# 2             0.772701          0.826444
# 20            0.772701          0.826444
# 72            0.624651          0.974446
# 28            0.622806          0.974446
# 26            0.622806          0.974446
# 39            0.807988          0.786756
# 61            0.807988          0.786756
# 52            0.807988          0.786756
# 9             0.807988          0.786756
# 99            0.676011          0.908479
# 77            0.653600          0.927620
# 76            0.566810          0.989479
# 35            0.780673          0.775003
# 59            0.780673          0.775003
# 48            0.780673          0.775003
# 5             0.780673          0.775003
# 23            0.780673          0.775003
# 65            0.551598          1.000000
# 71            0.529062          0.949716
# 55            0.594906          0.878619
# 42            0.594906          0.878619
# 64            0.594906          0.878619
# 12            0.594906          0.878619
# 70            0.636087          0.826444
# 78            0.515972          0.940861
# 100           0.629215          0.826444
# 75            0.662228          0.775003
# 69            0.630814          0.800463
# 68            0.581264          0.835411
# 87            0.601943          0.811848
# 67            0.610692          0.775003
# 83            0.526925          0.858563
# 51            0.629533          0.693326
# 24            0.629533          0.693326
# 49            0.629533          0.693326
# 8             0.629533          0.693326
# 6             0.629533          0.693326
# 38            0.629533          0.693326
# 36            0.629533          0.693326

# %%
#rank 50-100
initial_rank.sort_values(by='fit', ascending=False)[50:100]
# Out:
#       id                                          job_title  \
# 82    83          HR Manager at Endemol Shine North America
# 80    81  Senior Human Resources Business Partner at Hei...
# 74    75  Nortia Staffing is seeking Human Resources, Pa...
# 7      8                               HR Senior Specialist
# 37    38                               HR Senior Specialist
# 25    26                               HR Senior Specialist
# 60    61                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 73    74                       Human Resources Professional
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 13    14  2019 C.T. Bauer College of Business Graduate (...
# 14    15  2019 C.T. Bauer College of Business Graduate (...
# 56    57  2019 C.T. Bauer College of Business Graduate (...
# 18    19  2019 C.T. Bauer College of Business Graduate (...
# 30    31  2019 C.T. Bauer College of Business Graduate (...
# 43    44  2019 C.T. Bauer College of Business Graduate (...
# 91    92  Seeking employment opportunities within Custom...
# 58    59             People Development Coordinator at Ryan
# 33    34             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 21    22             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 46    47             People Development Coordinator at Ryan
# 41    42  SVP, CHRO, Marketing & Communications, CSR Off...
# 11    12  SVP, CHRO, Marketing & Communications, CSR Off...
# 63    64  SVP, CHRO, Marketing & Communications, CSR Off...
# 54    55  SVP, CHRO, Marketing & Communications, CSR Off...
# 88    89                    Director Human Resources  at EY
# 79    80           Junior MES Engineer| Information Systems
# 85    86  Information Systems Specialist and Programmer ...
# 62    63                      Student at Chapman University
# 10    11                      Student at Chapman University
# 53    54                      Student at Chapman University
# 40    41                      Student at Chapman University
# 95    96  Student at Indiana University Kokomo - Busines...
# 103  104   Director Of Administration at Excellence Logging
# 94    95              Student at Westfield State University
# 90    91       Lead Official at Western Illinois University
# 89    90  Undergraduate Research Assistant at Styczynski...
# 1      2  Native English Teacher at EPIK (English Progra...
# 44    45  Native English Teacher at EPIK (English Progra...
# 31    32  Native English Teacher at EPIK (English Progra...
# 19    20  Native English Teacher at EPIK (English Progra...
# 15    16  Native English Teacher at EPIK (English Progra...
# 92    93  Admissions Representative at Community medical...
# 86    87  Bachelor of Science in Biology from Victoria U...
# 102  103                     Always set them up for Success
# 97    98                                            Student
# 101  102   Business Intelligence and Analytics at Travelers
# 22    23    Advisory Board Member at Celal Bayar University
#
#                               location connection       fit  \
# 82             Los Angeles, California        268  0.516759
# 80         Chattanooga, Tennessee Area        455  0.515512
# 74                San Jose, California      500+   0.508964
# 7               San Francisco Bay Area      500+   0.505659
# 37              San Francisco Bay Area      500+   0.505659
# 25              San Francisco Bay Area      500+   0.505659
# 60              San Francisco Bay Area      500+   0.505659
# 50              San Francisco Bay Area      500+   0.505659
# 73                 Greater Boston Area         16  0.488397
# 0                       Houston, Texas         85  0.482357
# 13                      Houston, Texas         85  0.482357
# 14                      Houston, Texas         85  0.482357
# 56                      Houston, Texas         85  0.482357
# 18                      Houston, Texas         85  0.482357
# 30                      Houston, Texas         85  0.482357
# 43                      Houston, Texas         85  0.482357
# 91                Torrance, California         64  0.468904
# 58                       Denton, Texas      500+   0.438381
# 33                       Denton, Texas      500+   0.438381
# 3                        Denton, Texas      500+   0.438381
# 21                       Denton, Texas      500+   0.438381
# 17                       Denton, Texas      500+   0.438381
# 46                       Denton, Texas      500+   0.438381
# 41                 Houston, Texas Area      500+   0.408655
# 11                 Houston, Texas Area      500+   0.408655
# 63                 Houston, Texas Area      500+   0.408655
# 54                 Houston, Texas Area      500+   0.408655
# 88                Greater Atlanta Area        349  0.402270
# 79   Myrtle Beach, South Carolina Area         52  0.380059
# 85              Gaithersburg, Maryland          4  0.373059
# 62             Lake Forest, California          2  0.337337
# 10             Lake Forest, California          2  0.337337
# 53             Lake Forest, California          2  0.337337
# 40             Lake Forest, California          2  0.337337
# 95                  Lafayette, Indiana         19  0.332327
# 103                        Katy, Texas      500+   0.323407
# 94          Bridgewater, Massachusetts         57  0.313951
# 90                Greater Chicago Area         39  0.311376
# 89                Greater Atlanta Area        155  0.305675
# 1                               Kanada      500+   0.271673
# 44                              Kanada      500+   0.271673
# 31                              Kanada      500+   0.271673
# 19                              Kanada      500+   0.271673
# 15                              Kanada      500+   0.271673
# 92              Long Beach, California          9  0.267384
# 86                 Baltimore, Maryland         40  0.258381
# 102                        Los Angeles      500+   0.215943
# 97                 Houston, Texas Area          4  0.209740
# 101                           New York         49  0.209035
# 22                      İzmir, Türkiye      500+   0.208569
#
#      job_title_ranking  location_ranking
# 82            0.479823      8.491880e-01
# 80            0.474647      8.832888e-01
# 74            0.475273      8.121889e-01
# 7             0.472147      8.072641e-01
# 37            0.472147      8.072641e-01
# 25            0.472147      8.072641e-01
# 60            0.472147      8.072641e-01
# 50            0.472147      8.072641e-01
# 73            0.727106      2.496882e-01
# 0             0.427339      9.775191e-01
# 13            0.427339      9.775191e-01
# 14            0.427339      9.775191e-01
# 56            0.427339      9.775191e-01
# 18            0.427339      9.775191e-01
# 30            0.427339      9.775191e-01
# 43            0.427339      9.775191e-01
# 91            0.426725      8.485137e-01
# 58            0.377238      9.886667e-01
# 33            0.377238      9.886667e-01
# 3             0.377238      9.886667e-01
# 21            0.377238      9.886667e-01
# 17            0.377238      9.886667e-01
# 46            0.377238      9.886667e-01
# 41            0.345789      9.744458e-01
# 11            0.345789      9.744458e-01
# 63            0.345789      9.744458e-01
# 54            0.345789      9.744458e-01
# 88            0.557395      2.471460e-01
# 79            0.330157      8.291805e-01
# 85            0.325055      8.050966e-01
# 62            0.279871      8.545239e-01
# 10            0.279871      8.545239e-01
# 53            0.279871      8.545239e-01
# 40            0.279871      8.545239e-01
# 95            0.272473      8.710178e-01
# 103           0.250277      9.815774e-01
# 94            0.265768      7.475934e-01
# 90            0.249753      8.659842e-01
# 89            0.312178      2.471460e-01
# 1             0.224822      6.933263e-01
# 44            0.224822      6.933263e-01
# 31            0.224822      6.933263e-01
# 19            0.224822      6.933263e-01
# 15            0.224822      6.933263e-01
# 92            0.202660      8.499005e-01
# 86            0.198204      7.999698e-01
# 102           0.145582      8.491880e-01
# 97            0.124772      9.744458e-01
# 101           0.146150      7.750032e-01
# 22            0.231743      1.110223e-16

# %%
#suppose from the above we notice that id 82 is the ideal candidate (6th in top 50)
job_query = initial_rank['job_title'].loc[81]
location_query = initial_rank['location'].loc[81]
re_rank = ranking(initial_rank, job_query, location_query)
re_rank
# Out:
#       id                                          job_title  \
# 0      1  2019 C.T. Bauer College of Business Graduate (...
# 1      2  Native English Teacher at EPIK (English Progra...
# 2      3              Aspiring Human Resources Professional
# 3      4             People Development Coordinator at Ryan
# 4      5    Advisory Board Member at Celal Bayar University
# ..   ...                                                ...
# 99   100  Aspiring Human Resources Manager | Graduating ...
# 100  101              Human Resources Generalist at Loparex
# 101  102   Business Intelligence and Analytics at Travelers
# 102  103                     Always set them up for Success
# 103  104   Director Of Administration at Excellence Logging
#
#                                 location connection       fit  \
# 0                         Houston, Texas         85  0.762975
# 1                                 Kanada      500+   0.272326
# 2    Raleigh-Durham, North Carolina Area         44  0.835364
# 3                          Denton, Texas      500+   0.438696
# 4                         İzmir, Türkiye      500+   0.227434
# ..                                   ...        ...       ...
# 99              Cape Girardeau, Missouri        103  0.801518
# 100  Raleigh-Durham, North Carolina Area      500+   0.667025
# 101                             New York         49  0.147973
# 102                          Los Angeles      500+   0.208359
# 103                          Katy, Texas      500+   0.390420
#
#      job_title_ranking  location_ranking
# 0             0.548467      9.774830e-01
# 1             0.228571      6.661207e-01
# 2             0.848949      8.217797e-01
# 3             0.379807      9.686977e-01
# 4             0.252705      1.110223e-16
# ..                 ...               ...
# 99            0.706828      8.962081e-01
# 100           0.512269      8.217797e-01
# 101           0.079071      7.680892e-01
# 102           0.141295      8.119406e-01
# 103           0.324732      9.816142e-01
#
# [104 rows x 7 columns]

# %%
#top 50
initial_rank.sort_values(by='fit', ascending=False)[0:50]
# Out:
#      id                                          job_title  \
# 81   82  Aspiring Human Resources Professional | An ene...
# 96   97              Aspiring Human Resources Professional
# 20   21              Aspiring Human Resources Professional
# 16   17              Aspiring Human Resources Professional
# 32   33              Aspiring Human Resources Professional
# 57   58              Aspiring Human Resources Professional
# 2     3              Aspiring Human Resources Professional
# 45   46              Aspiring Human Resources Professional
# 65   66  Experienced Retail Manager and aspiring Human ...
# 66   67  Human Resources, Staffing and Recruiting Profe...
# 26   27  Aspiring Human Resources Management student se...
# 28   29  Aspiring Human Resources Management student se...
# 99  100  Aspiring Human Resources Manager | Graduating ...
# 71   72  Business Management Major and Aspiring Human R...
# 72   73  Aspiring Human Resources Manager, seeking inte...
# 5     6                Aspiring Human Resources Specialist
# 23   24                Aspiring Human Resources Specialist
# 48   49                Aspiring Human Resources Specialist
# 59   60                Aspiring Human Resources Specialist
# 35   36                Aspiring Human Resources Specialist
# 76   77  Human Resources|\nConflict Management|\nPolici...
# 78   79  Liberal Arts Major. Aspiring Human Resources A...
# 30   31  2019 C.T. Bauer College of Business Graduate (...
# 56   57  2019 C.T. Bauer College of Business Graduate (...
# 0     1  2019 C.T. Bauer College of Business Graduate (...
# 18   19  2019 C.T. Bauer College of Business Graduate (...
# 14   15  2019 C.T. Bauer College of Business Graduate (...
# 13   14  2019 C.T. Bauer College of Business Graduate (...
# 43   44  2019 C.T. Bauer College of Business Graduate (...
# 98   99                   Seeking Human Resources Position
# 75   76  Aspiring Human Resources Professional | Passio...
# 64   65  Human Resources Coordinator at InterContinenta...
# 42   43  Human Resources Coordinator at InterContinenta...
# 12   13  Human Resources Coordinator at InterContinenta...
# 55   56  Human Resources Coordinator at InterContinenta...
# 27   28              Seeking Human Resources Opportunities
# 29   30              Seeking Human Resources Opportunities
# 87   88                   Human Resources Management Major
# 77   78             Human Resources Generalist at Schwan's
# 83   84  Human Resources professional for the world lea...
# 61   62  Seeking Human Resources HRIS and Generalist Po...
# 52   53  Seeking Human Resources HRIS and Generalist Po...
# 39   40  Seeking Human Resources HRIS and Generalist Po...
# 9    10  Seeking Human Resources HRIS and Generalist Po...
# 80   81  Senior Human Resources Business Partner at Hei...
# 70   71    Human Resources Generalist at ScottMadden, Inc.
# 67   68            Human Resources Specialist at Luxottica
# 7     8                               HR Senior Specialist
# 37   38                               HR Senior Specialist
# 60   61                               HR Senior Specialist
#
#                                location connection       fit  \
# 81                   Austin, Texas Area        174  1.000000
# 96                 Kokomo, Indiana Area         71  0.850930
# 20  Raleigh-Durham, North Carolina Area         44  0.835364
# 16  Raleigh-Durham, North Carolina Area         44  0.835364
# 32  Raleigh-Durham, North Carolina Area         44  0.835364
# 57  Raleigh-Durham, North Carolina Area         44  0.835364
# 2   Raleigh-Durham, North Carolina Area         44  0.835364
# 45  Raleigh-Durham, North Carolina Area         44  0.835364
# 65                   Austin, Texas Area         57  0.825092
# 66            Jackson, Mississippi Area      500+   0.807625
# 26                  Houston, Texas Area      500+   0.806396
# 28                  Houston, Texas Area      500+   0.806396
# 99             Cape Girardeau, Missouri        103  0.801518
# 71               Monroe, Louisiana Area          5  0.797952
# 72                  Houston, Texas Area          7  0.795466
# 5                              New York          1  0.790953
# 23                             New York          1  0.790953
# 48                             New York          1  0.790953
# 59                             New York          1  0.790953
# 35                             New York          1  0.790953
# 76               Dallas/Fort Worth Area        409  0.765833
# 78          Baton Rouge, Louisiana Area          7  0.764137
# 30                       Houston, Texas         85  0.762975
# 56                       Houston, Texas         85  0.762975
# 0                        Houston, Texas         85  0.762975
# 18                       Houston, Texas         85  0.762975
# 14                       Houston, Texas         85  0.762975
# 13                       Houston, Texas         85  0.762975
# 43                       Houston, Texas         85  0.762975
# 98               Las Vegas, Nevada Area         48  0.752476
# 75                   New York, New York        212  0.744936
# 64                     Atlanta, Georgia      500+   0.736618
# 42                     Atlanta, Georgia      500+   0.736618
# 12                     Atlanta, Georgia      500+   0.736618
# 55                     Atlanta, Georgia      500+   0.736618
# 27                    Chicago, Illinois        390  0.732454
# 29                    Chicago, Illinois        390  0.732454
# 87                 Milpitas, California         18  0.719151
# 77          Amerika Birleşik Devletleri      500+   0.717264
# 83                 Highland, California         50  0.711010
# 61            Greater Philadelphia Area      500+   0.704837
# 52            Greater Philadelphia Area      500+   0.704837
# 39            Greater Philadelphia Area      500+   0.704837
# 9             Greater Philadelphia Area      500+   0.704837
# 80          Chattanooga, Tennessee Area        455  0.689483
# 70  Raleigh-Durham, North Carolina Area      500+   0.676258
# 67                             New York      500+   0.674833
# 7                San Francisco Bay Area      500+   0.670480
# 37               San Francisco Bay Area      500+   0.670480
# 60               San Francisco Bay Area      500+   0.670480
#
#     job_title_ranking  location_ranking
# 81           1.000000          1.000000
# 96           0.848949          0.852911
# 20           0.848949          0.821780
# 16           0.848949          0.821780
# 32           0.848949          0.821780
# 57           0.848949          0.821780
# 2            0.848949          0.821780
# 45           0.848949          0.821780
# 65           0.650185          1.000000
# 66           0.699659          0.915590
# 26           0.638223          0.974569
# 28           0.638223          0.974569
# 99           0.706828          0.896208
# 71           0.652052          0.943851
# 72           0.616363          0.974569
# 5            0.813817          0.768089
# 23           0.813817          0.768089
# 48           0.813817          0.768089
# 59           0.813817          0.768089
# 35           0.813817          0.768089
# 76           0.559168          0.972498
# 78           0.588836          0.939438
# 30           0.548467          0.977483
# 56           0.548467          0.977483
# 0            0.548467          0.977483
# 18           0.548467          0.977483
# 14           0.548467          0.977483
# 13           0.548467          0.977483
# 43           0.548467          0.977483
# 98           0.671188          0.833763
# 75           0.721782          0.768089
# 64           0.598829          0.874407
# 42           0.598829          0.874407
# 12           0.598829          0.874407
# 55           0.598829          0.874407
# 27           0.614983          0.849925
# 29           0.614983          0.849925
# 87           0.663500          0.774801
# 77           0.537776          0.896752
# 83           0.600896          0.821124
# 61           0.629650          0.780024
# 52           0.629650          0.780024
# 39           0.629650          0.780024
# 9            0.629650          0.780024
# 80           0.501802          0.877165
# 70           0.530737          0.821780
# 67           0.581577          0.768089
# 7            0.570681          0.770280
# 37           0.570681          0.770280
# 60           0.570681          0.770280

# %%
#rank 50-100
initial_rank.sort_values(by='fit', ascending=False)[50:100]
# Out:
#       id                                          job_title  \
# 25    26                               HR Senior Specialist
# 50    51                               HR Senior Specialist
# 69    70  Retired Army National Guard Recruiter, office ...
# 68    69  Director of Human Resources North America, Gro...
# 100  101              Human Resources Generalist at Loparex
# 24    25  Student at Humber College and Aspiring Human R...
# 51    52  Student at Humber College and Aspiring Human R...
# 36    37  Student at Humber College and Aspiring Human R...
# 6      7  Student at Humber College and Aspiring Human R...
# 49    50  Student at Humber College and Aspiring Human R...
# 8      9  Student at Humber College and Aspiring Human R...
# 38    39  Student at Humber College and Aspiring Human R...
# 82    83          HR Manager at Endemol Shine North America
# 73    74                       Human Resources Professional
# 93    94  Seeking Human  Resources Opportunities. Open t...
# 21    22             People Development Coordinator at Ryan
# 58    59             People Development Coordinator at Ryan
# 33    34             People Development Coordinator at Ryan
# 17    18             People Development Coordinator at Ryan
# 3      4             People Development Coordinator at Ryan
# 46    47             People Development Coordinator at Ryan
# 79    80           Junior MES Engineer| Information Systems
# 85    86  Information Systems Specialist and Programmer ...
# 11    12  SVP, CHRO, Marketing & Communications, CSR Off...
# 41    42  SVP, CHRO, Marketing & Communications, CSR Off...
# 63    64  SVP, CHRO, Marketing & Communications, CSR Off...
# 54    55  SVP, CHRO, Marketing & Communications, CSR Off...
# 103  104   Director Of Administration at Excellence Logging
# 74    75  Nortia Staffing is seeking Human Resources, Pa...
# 88    89                    Director Human Resources  at EY
# 90    91       Lead Official at Western Illinois University
# 95    96  Student at Indiana University Kokomo - Busines...
# 10    11                      Student at Chapman University
# 62    63                      Student at Chapman University
# 53    54                      Student at Chapman University
# 40    41                      Student at Chapman University
# 89    90  Undergraduate Research Assistant at Styczynski...
# 94    95              Student at Westfield State University
# 91    92  Seeking employment opportunities within Custom...
# 97    98                                            Student
# 15    16  Native English Teacher at EPIK (English Progra...
# 31    32  Native English Teacher at EPIK (English Progra...
# 1      2  Native English Teacher at EPIK (English Progra...
# 44    45  Native English Teacher at EPIK (English Progra...
# 19    20  Native English Teacher at EPIK (English Progra...
# 86    87  Bachelor of Science in Biology from Victoria U...
# 22    23    Advisory Board Member at Celal Bayar University
# 34    35    Advisory Board Member at Celal Bayar University
# 4      5    Advisory Board Member at Celal Bayar University
# 47    48    Advisory Board Member at Celal Bayar University
#
#                                 location connection       fit  \
# 25                San Francisco Bay Area      500+   0.670480
# 50                San Francisco Bay Area      500+   0.670480
# 69              Virginia Beach, Virginia         82  0.669077
# 68                              Michigan      500+   0.667600
# 100  Raleigh-Durham, North Carolina Area      500+   0.667025
# 24                                Kanada         61  0.661357
# 51                                Kanada         61  0.661357
# 36                                Kanada         61  0.661356
# 6                                 Kanada         61  0.661356
# 49                                Kanada         61  0.661356
# 8                                 Kanada         61  0.661356
# 38                                Kanada         61  0.661356
# 82               Los Angeles, California        268  0.518892
# 73                   Greater Boston Area         16  0.501327
# 93           Amerika Birleşik Devletleri        415  0.447982
# 21                         Denton, Texas      500+   0.438696
# 58                         Denton, Texas      500+   0.438696
# 33                         Denton, Texas      500+   0.438696
# 17                         Denton, Texas      500+   0.438696
# 3                          Denton, Texas      500+   0.438696
# 46                         Denton, Texas      500+   0.438696
# 79     Myrtle Beach, South Carolina Area         52  0.427771
# 85                Gaithersburg, Maryland          4  0.421121
# 11                   Houston, Texas Area      500+   0.394112
# 41                   Houston, Texas Area      500+   0.394112
# 63                   Houston, Texas Area      500+   0.394112
# 54                   Houston, Texas Area      500+   0.394112
# 103                          Katy, Texas      500+   0.390420
# 74                  San Jose, California      500+   0.386099
# 88                  Greater Atlanta Area        349  0.380457
# 90                  Greater Chicago Area         39  0.369119
# 95                    Lafayette, Indiana         19  0.359382
# 10               Lake Forest, California          2  0.335895
# 62               Lake Forest, California          2  0.335895
# 53               Lake Forest, California          2  0.335895
# 40               Lake Forest, California          2  0.335895
# 89                  Greater Atlanta Area        155  0.331642
# 94            Bridgewater, Massachusetts         57  0.311548
# 91                  Torrance, California         64  0.309930
# 97                   Houston, Texas Area          4  0.296044
# 15                                Kanada      500+   0.272326
# 31                                Kanada      500+   0.272326
# 1                                 Kanada      500+   0.272326
# 44                                Kanada      500+   0.272326
# 19                                Kanada      500+   0.272326
# 86                   Baltimore, Maryland         40  0.248096
# 22                        İzmir, Türkiye      500+   0.227434
# 34                        İzmir, Türkiye      500+   0.227434
# 4                         İzmir, Türkiye      500+   0.227434
# 47                        İzmir, Türkiye      500+   0.227434
#
#      job_title_ranking  location_ranking
# 25            0.570681      7.702797e-01
# 50            0.570681      7.702797e-01
# 69            0.542304      7.958493e-01
# 68            0.514202      8.209985e-01
# 100           0.512269      8.217797e-01
# 24            0.656592      6.661207e-01
# 51            0.656592      6.661207e-01
# 36            0.656592      6.661207e-01
# 6             0.656592      6.661207e-01
# 49            0.656592      6.661207e-01
# 8             0.656592      6.661207e-01
# 38            0.656592      6.661207e-01
# 82            0.486331      8.119406e-01
# 73            0.756637      2.460173e-01
# 93            0.398118      8.967522e-01
# 21            0.379807      9.686977e-01
# 58            0.379807      9.686977e-01
# 33            0.379807      9.686977e-01
# 17            0.379807      9.686977e-01
# 3             0.379807      9.686977e-01
# 46            0.379807      9.686977e-01
# 79            0.383482      8.263698e-01
# 85            0.379213      7.982895e-01
# 11            0.329616      9.745695e-01
# 41            0.329616      9.745695e-01
# 63            0.329616      9.745695e-01
# 54            0.329616      9.745695e-01
# 103           0.324732      9.816142e-01
# 74            0.342872      7.751415e-01
# 88            0.517475      2.434392e-01
# 90            0.315606      8.507359e-01
# 95            0.304024      8.576002e-01
# 10            0.282407      8.172858e-01
# 62            0.282407      8.172858e-01
# 53            0.282407      8.172858e-01
# 40            0.282407      8.172858e-01
# 89            0.341443      2.434392e-01
# 94            0.263860      7.407395e-01
# 91            0.254219      8.113348e-01
# 97            0.220652      9.745695e-01
# 15            0.228571      6.661207e-01
# 31            0.228571      6.661207e-01
# 1             0.228571      6.661207e-01
# 44            0.228571      6.661207e-01
# 19            0.228571      6.661207e-01
# 86            0.187523      7.932482e-01
# 22            0.252705      1.110223e-16
# 34            0.252705      1.110223e-16
# 4             0.252705      1.110223e-16
# 47            0.252705      1.110223e-16

# %% [markdown]
# Success Metrics:
#
# Rank candidates based on a fitness score - Done using cosine similarity and location ranking
#
# Re-rank candidates when a candidate is starred - Done (same approach to the above)

# %% [markdown]
# Overall my recommendation is to go with BERT-based ranking algorithm due to its high relevancy (measured through manual inspection) when compared to Glove.
#
# In the case of Glove, we can see that certain candidates who should not be in the list is included in top 50. For example - candidates with job title 'People Development Coordinator at Ryan' and 'Director Of Administration at Excellence Logging'. In the case of BERT, we can see that almost all of the human resources related candidates are ranked higher than others. This might be due to the fact that BERT is more suited for understanding the semantic relationship in sentences than Glove.

# %% [markdown]
# Bonus:
#
# 1. We are interested in a robust algorithm, tell us how your solution works and show us how your ranking gets better with each starring action?
# - I have used word embeddings and location api to rank the candidates based on search query, and each time a starring action is performed, the candidate list is updated using the ideal candidate's job title and location as the search query.
#
# 2. How can we filter out candidates which in the first place should not be in this list?
# - We can pick a ranking threshold of 0.5 to filter out the candidates who should not be in the list. This method works for BERT than Glove.
#
# 3. Can we determine a cut-off point that would work for other roles without losing high potential candidates?
# - See above answer
#
# 4. Do you have any ideas that we should explore so that we can even automate this procedure to prevent human bias?
# - Currently, we are using human intervention to find ideal candidates. In the future, we could potentially use human expertise to create a  labelled dataset and utilize a 'Learning to Rank' algorithm to train a neural network, which could then be used in production for ranking these candidates, thus limiting any human bias (Note: labelling should be done using a diverse group of subject matter experts). Creating a labelled dataset could be as simple as adding an option to rank each result as relevant, somewhat relevant and not relevant. A similar system is explained here in this article - https://embracingtherandom.com/machine-learning/tensorflow/ranking/deep-learning/learning-to-rank-part-1/
